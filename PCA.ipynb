# %%
import mnist
import matplotlib.pyplot as plt
from kmeans.basic import kmeans
import numpy as np
from sklearn.decomposition import PCA
import pandas
from stars import load_stars

# %%
m = mnist.mnist()

# %%
pca = PCA(n_components=3)

# %%
d = pca.fit_transform(load_stars())

# %%
d_min = np.min(d)
d_max = np.max(d)

# %%
d = (d - d_min) / (d_max - d_min)

# %%
c, a, l = kmeans(load_stars(), 6)

# %%
plt.plot(l)
print(l[-1])
plt.show()
# Out:
# 0.3412204859335595

# %%
plt.scatter(d[:,0],d[:,1], c=a)
plt.show()

# %%
c_i = pca.inverse_transform(c)
for i in range(10):
    plt.imshow(np.reshape(c_i[i], (28, 28)))
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-5203ab7afd27> in <module>
# ----> 1 c_i = pca.inverse_transform(c)
#       2 for i in range(10):
#       3     plt.imshow(np.reshape(c_i[i], (28, 28)))
#       4     plt.show()
#
# ~\anaconda3\lib\site-packages\sklearn\decomposition\_base.py in inverse_transform(self, X)
#     157                             self.components_) + self.mean_
#     158         else:
# --> 159             return np.dot(X, self.components_) + self.mean_
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# ValueError: shapes (10,4) and (3,4) not aligned: 4 (dim 1) != 3 (dim 0)
