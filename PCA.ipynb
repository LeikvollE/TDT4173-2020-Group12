# %%
import mnist
import matplotlib.pyplot as plt
from kmeans.basic import kmeans
from kmeans.kmeanspp import kmeanspp
import numpy as np
from sklearn.decomposition import PCA
import pandas
from stars import load_stars

# %%
m = mnist.mnist()

# %%
pca = PCA(n_components=500)

# %%
#d = pca.fit_transform(load_stars())
m = mnist.mnist()
#d = pca.fit_transform(m.get_test_set())
d = m.get_test_set()

# %%
d_min = np.min(d)
d_max = np.max(d)

# %%
#d = (d - d_min) / (d_max - d_min)

# %%
c, a, l = kmeans(d, 10, 1)
# Out:
# run: 0

# %%
plt.plot(l)
plt.xticks(range(0,len(l)))
plt.ylabel("Loss")
plt.xlabel("Iterations")
print(l[-1])
print(len(l))
plt.show()
# Out:
# 63301.647055149595
# 148

# %%
print(m.get_accuracy(a, 'test'))
# Out:
# ([(0.6666592593415629, 1.0), (0.33332962967078145, 2.0), (0.11110987655692715, 3.0), (0.4444395062277086, 5.0), (0.8888790124554172, 6.0), (0.0, 8.0), (0.7777691358984901, 9.0)], 0.524)

# %%
#c_i = pca.inverse_transform(c)
for i in range(10):
    plt.imshow(np.reshape(c[i], (28, 28)))
    plt.show()
