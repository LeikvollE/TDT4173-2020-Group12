# %%
import mnist
import matplotlib.pyplot as plt
from kmeans.basic import kmeans
from kmeans.kmeanspp import kmeanspp
import numpy as np
from sklearn.decomposition import PCA
import pandas
from stars import load_stars

# %%
m = mnist.mnist()

# %%
pca = PCA(n_components=200)

# %%
#d = pca.fit_transform(load_stars())
m = mnist.mnist()
d = pca.fit_transform(m.get_test_set())

# %%
d_min = np.min(d)
d_max = np.max(d)

# %%
#d = (d - d_min) / (d_max - d_min)

# %%
c, a, l = kmeanspp(d, 10)

# %%
plt.plot(l)
plt.xticks(range(0,len(l)))
plt.ylabel("Loss")
plt.xlabel("Iterations")
print(l[-1])
print(len(l))
plt.show()
# Out:
# 60299.67164031456
# 94

# %%
print(m.get_accuracy(a, 'test'))
# Out:
# ([(0.8888790124554172, 0.0), (0.7777691358984901, 1.0), (0.9999888890123443, 2.0), (0.6666592593415629, 3.0), (0.2222197531138543, 4.0), (0.5555493827846357, 5.0), (0.33332962967078145, 6.0), (0.0, 7.0), (0.4444395062277086, 8.0), (0.11110987655692715, 9.0)], 0.6056)

# %%
c_i = pca.inverse_transform(c)
for i in range(10):
    plt.imshow(np.reshape(c_i[i], (28, 28)))
    plt.show()
